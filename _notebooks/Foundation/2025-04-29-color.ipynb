# %% [markdown]
# ### ▶️ **Exercise 1 – Color Codes**
#
# **Convert these hex codes to RGB & RGBA (A = 1):**
#
# 1. `#1E90FF`
#
#    * RGB: `rgb(30, 144, 255)`
#    * RGBA: `rgba(30, 144, 255, 1)`
#
# 2. `#32CD32`
#
#    * RGB: `rgb(50, 205, 50)`
#    * RGBA: `rgba(50, 205, 50, 1)`
#
# 3. `#FFD700`
#
#    * RGB: `rgb(255, 215, 0)`
#    * RGBA: `rgba(255, 215, 0, 1)`
#
# **Write an RGBA for 50%-transparent teal (rgb(0, 128, 128)):**
#
# * RGBA: `rgba(0, 128, 128, 0.5)`
#
# ---
#
# ### ▶️ **Exercise 2 – Digital Images**
#
# **Design a 2×2 icon – Pick 4 colors, list each hex code:**
#
# * Top-left: `#FF0000` (Red)
# * Top-right: `#00FF00` (Green)
# * Bottom-left: `#0000FF` (Blue)
# * Bottom-right: `#FFFF00` (Yellow)
#
# **Calculate storage for 2×2 image at 24-bit color depth:**
#
# * 24 bits/pixel × 4 pixels = **96 bits**
#
# ---
#
# ### ▶️ **Exercise 3 – Base64 Encoding**
#
# **Base64-encode the string: `Cat`**
#
# * Text → ASCII: `C` = 67, `a` = 97, `t` = 116
# * Bytes: `[0x43, 0x61, 0x74]`
# * Binary: `01000011 01100001 01110100`
# * Chunks: `010000 110110 000101 110100`
# * Base64 characters: `"Q2F0"`
#
# ✅ **Answer**: `"Q2F0"`
#
# **Create a 1×1 red PNG, convert it to Base64, and embed in `<img>` tag:**
#
# A standard 1×1 red PNG (already converted) would look something like this:
#
# ```html
# <img src="..." />
# ``
