# %% [raw]
# ---
# toc: true
# comments: false
# layout: post
# type: hacks
# courses: { compsci: {week: 26} }
# title: Questions and Answers
# ---

# %% [markdown]
# <div style="font-family: Arial, sans-serif; background: #ffffff; padding: 20px; border-radius: 12px; border: 1px solid #ddd; max-width: 900px; margin: auto;">
#
#   <style>
#     .question-box {
#       margin-bottom: 20px;
#     }
#     .question-box strong {
#       display: block;
#       margin-bottom: 8px;
#       font-size: 1.1em;
#       color: #111;
#     }
#     button {
#       background-color: #0044cc;
#       color: white;
#       padding: 8px 14px;
#       border: none;
#       border-radius: 5px;
#       font-weight: bold;
#       cursor: pointer;
#       margin-top: 4px;
#     }
#     .answer-box {
#       display: none;
#       margin-top: 10px;
#       background: #f4f4f4;
#       padding: 12px;
#       border-left: 5px solid #0044cc;
#       border-radius: 6px;
#       color: #222;
#     }
#   </style>
#
#   <script>
#     function toggleAnswer(id) {
#       const answer = document.getElementById(id);
#       answer.style.display = (answer.style.display === 'block') ? 'none' : 'block';
#     }
#   </script>
#
#   <h2>🧠 Interactive Q&A – Big Idea 3 & 5</h2>
#
#   <!-- Begin Q&A Blocks -->
#   <div class="question-box">
#     <strong>1. What is a procedure and why is it useful?</strong>
#     <button onclick="toggleAnswer('a1')">Show Answer</button>
#     <div id="a1" class="answer-box">A procedure is a block of code designed to perform a specific task. It reduces repetition and simplifies programs.</div>
#   </div>
#
#   <div class="question-box">
#     <strong>2. What are parameters in a function?</strong>
#     <button onclick="toggleAnswer('a2')">Show Answer</button>
#     <div id="a2" class="answer-box">Parameters allow a function to accept input values and operate on different data when called.</div>
#   </div>
#
#   <div class="question-box">
#     <strong>3. What is the purpose of a return value?</strong>
#     <button onclick="toggleAnswer('a3')">Show Answer</button>
#     <div id="a3" class="answer-box">Return values send results back from a function to be used elsewhere in the program.</div>
#   </div>
#
#   <div class="question-box">
#     <strong>4. How does a conditional statement work?</strong>
#     <button onclick="toggleAnswer('a4')">Show Answer</button>
#     <div id="a4" class="answer-box">Conditional statements run code only when certain conditions are true using if/elif/else.</div>
#   </div>
#
#   <div class="question-box">
#     <strong>5. What does Boolean logic help you do?</strong>
#     <button onclick="toggleAnswer('a5')">Show Answer</button>
#     <div id="a5" class="answer-box">It helps make decisions in code using logical operators like and, or, and not.</div>
#   </div>
#
#   <div class="question-box">
#     <strong>6. What’s the difference between a while loop and a for loop?</strong>
#     <button onclick="toggleAnswer('a6')">Show Answer</button>
#     <div id="a6" class="answer-box">A for loop repeats a set number of times, while a while loop runs based on a condition.</div>
#   </div>
#
#   <div class="question-box">
#     <strong>7. How do lists help manage complexity in code?</strong>
#     <button onclick="toggleAnswer('a7')">Show Answer</button>
#     <div id="a7" class="answer-box">Lists store groups of data, allowing loops and filters to operate on many values with less code.</div>
#   </div>
#
#   <div class="question-box">
#     <strong>8. What is algorithmic bias?</strong>
#     <button onclick="toggleAnswer('a8')">Show Answer</button>
#     <div id="a8" class="answer-box">Bias in code caused by flawed data or assumptions, leading to unfair or inaccurate results.</div>
#   </div>
#
#   <div class="question-box">
#     <strong>9. What are examples of algorithmic bias?</strong>
#     <button onclick="toggleAnswer('a9')">Show Answer</button>
#     <div id="a9" class="answer-box">Examples include facial recognition failing on darker skin or AI job filters excluding women.</div>
#   </div>
#
#   <div class="question-box">
#     <strong>10. What is the digital divide?</strong>
#     <button onclick="toggleAnswer('a10')">Show Answer</button>
#     <div id="a10" class="answer-box">The gap between people who have access to modern technology and those who don’t.</div>
#   </div>
#
#   <div class="question-box">
#     <strong>11. Why is the digital divide a problem?</strong>
#     <button onclick="toggleAnswer('a11')">Show Answer</button>
#     <div id="a11" class="answer-box">It prevents equal access to education, healthcare, and opportunities in a digital world.</div>
#   </div>
#
#   <div class="question-box">
#     <strong>12. What can reduce the digital divide?</strong>
#     <button onclick="toggleAnswer('a12')">Show Answer</button>
#     <div id="a12" class="answer-box">Solutions include affordable internet, school tech programs, and digital literacy education.</div>
#   </div>
#
# </div>
